# %%
import pandas as pd
import numpy as np
import scipy as sp
import gensim
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
# %matplotlib inline

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models, matutils

# %% [markdown]
# Importing all Presidential speeches and appending them to a dataframe

# %%
from os import path
from pathlib import Path
import os
import glob
from collections import defaultdict
root=r'C:\Users\hartg\Desktop\Professional_Projects\Professional-Projects\MSF_Case_Study\Corpus of Presential Speeches\combined'
files=os.listdir(root)

#load speeches into a list

docs=list()
for file in files:
    with open(path.join(root,file),'r',encoding='utf-8') as fd:
        txt=fd.read()
        docs.append(txt)

# %% [markdown]
# Function that "cleans" the speeches. Re (regular expression) replaces special characters with, in this case, nothing. This will remove the <title=> characters, etc

# %%
import re
def clean(doc):
    doc = re.sub(r'[^\w\s]*','',doc)
    doc = re.sub(r'[\s]+', ' ', doc)
    doc = doc.lower().strip()
    return doc

# %% [markdown]
# clean the documents associated with the presidential speeches

# %%
clean_docs=list()
for doc in docs:
    doc = clean(doc)
    clean_docs.append(doc)

# %%
speeches_df=pd.DataFrame(docs)
speeches_df.columns=['text']

# %%
speeches_df.head()
# Out:
#                                                 text
# 0  <title="Special Session Message to Congress">\...
# 1  <title="Inaugural Address">\n<date="March 4, 1...
# 2  <title="Second Annual Message">\n<date="Decemb...
# 3  <title="Proclamation of Day of Fasting, Humili...
# 4  <title="Third Annual Message">\n<date="Decembe...

# %%
new_df=speeches_df['text'].str.split("=",n=1,expand=True)
new_df.columns=['title_bad','title_actual']
new_df.head()
# Out:
#   title_bad                                       title_actual
# 0    <title  "Special Session Message to Congress">\n<date=...
# 1    <title  "Inaugural Address">\n<date="March 4, 1797">\n...
# 2    <title  "Second Annual Message">\n<date="December 8, 1...
# 3    <title  "Proclamation of Day of Fasting, Humiliation a...
# 4    <title  "Third Annual Message">\n<date="December 3, 17...

# %%
new_df2=new_df['title_actual'].str.split("=",n=1,expand=True)
new_df2.columns=['title','date_and_text']
new_df2.head()
# Out:
#                                                title  \
# 0      "Special Session Message to Congress">\n<date
# 1                        "Inaugural Address">\n<date
# 2                    "Second Annual Message">\n<date
# 3  "Proclamation of Day of Fasting, Humiliation a...
# 4                     "Third Annual Message">\n<date
#
#                                        date_and_text
# 0  "May 16, 1797">\nThe personal inconveniences t...
# 1  "March 4, 1797">\nWhen it was first perceived,...
# 2  "December 8, 1798">\nGentlemen of the Senate a...
# 3  "March 23, 1798">\nAs the safety and prosperit...
# 4  "December 3, 1799">\nIt is with peculiar satis...

# %%
new_df3=new_df2['date_and_text'].str.split(">",n=1,expand=True)
new_df3.columns=['date','text']

# %%
new_df3.head()
# Out:
#                  date                                               text
# 0      "May 16, 1797"  \nThe personal inconveniences to the members o...
# 1     "March 4, 1797"  \nWhen it was first perceived, in early times,...
# 2  "December 8, 1798"  \nGentlemen of the Senate and Gentlemen of the...
# 3    "March 23, 1798"  \nAs the safety and prosperity of nations ulti...
# 4  "December 3, 1799"  \nIt is with peculiar satisfaction that I meet...

# %%
speeches=pd.merge(new_df2,new_df3,left_index=True,right_index=True)

# %%
speeches.head()
# Out:
#                                                title  \
# 0      "Special Session Message to Congress">\n<date
# 1                        "Inaugural Address">\n<date
# 2                    "Second Annual Message">\n<date
# 3  "Proclamation of Day of Fasting, Humiliation a...
# 4                     "Third Annual Message">\n<date
#
#                                        date_and_text                date  \
# 0  "May 16, 1797">\nThe personal inconveniences t...      "May 16, 1797"
# 1  "March 4, 1797">\nWhen it was first perceived,...     "March 4, 1797"
# 2  "December 8, 1798">\nGentlemen of the Senate a...  "December 8, 1798"
# 3  "March 23, 1798">\nAs the safety and prosperit...    "March 23, 1798"
# 4  "December 3, 1799">\nIt is with peculiar satis...  "December 3, 1799"
#
#                                                 text
# 0  \nThe personal inconveniences to the members o...
# 1  \nWhen it was first perceived, in early times,...
# 2  \nGentlemen of the Senate and Gentlemen of the...
# 3  \nAs the safety and prosperity of nations ulti...
# 4  \nIt is with peculiar satisfaction that I meet...

# %%
speeches.drop(['date_and_text'],axis=1,inplace=True)

# %%
speeches['title']=speeches.title.str.replace('>\n<date','',regex=True)
speeches.head()
# Out:
#                                                title                date  \
# 0              "Special Session Message to Congress"      "May 16, 1797"
# 1                                "Inaugural Address"     "March 4, 1797"
# 2                            "Second Annual Message"  "December 8, 1798"
# 3  "Proclamation of Day of Fasting, Humiliation a...    "March 23, 1798"
# 4                             "Third Annual Message"  "December 3, 1799"
#
#                                                 text
# 0  \nThe personal inconveniences to the members o...
# 1  \nWhen it was first perceived, in early times,...
# 2  \nGentlemen of the Senate and Gentlemen of the...
# 3  \nAs the safety and prosperity of nations ulti...
# 4  \nIt is with peculiar satisfaction that I meet...

# %%
speeches['date']=speeches.date.str.replace('"','',regex=True)
speeches.head()
# Out:
#                                                title              date  \
# 0              "Special Session Message to Congress"      May 16, 1797
# 1                                "Inaugural Address"     March 4, 1797
# 2                            "Second Annual Message"  December 8, 1798
# 3  "Proclamation of Day of Fasting, Humiliation a...    March 23, 1798
# 4                             "Third Annual Message"  December 3, 1799
#
#                                                 text
# 0  \nThe personal inconveniences to the members o...
# 1  \nWhen it was first perceived, in early times,...
# 2  \nGentlemen of the Senate and Gentlemen of the...
# 3  \nAs the safety and prosperity of nations ulti...
# 4  \nIt is with peculiar satisfaction that I meet...

# %%
speeches['text']=speeches.text.str.replace("\n",'',regex=True)
speeches.head()
# Out:
#                                                title              date  \
# 0              "Special Session Message to Congress"      May 16, 1797
# 1                                "Inaugural Address"     March 4, 1797
# 2                            "Second Annual Message"  December 8, 1798
# 3  "Proclamation of Day of Fasting, Humiliation a...    March 23, 1798
# 4                             "Third Annual Message"  December 3, 1799
#
#                                                 text
# 0  The personal inconveniences to the members of ...
# 1  When it was first perceived, in early times, t...
# 2  Gentlemen of the Senate and Gentlemen of the H...
# 3  As the safety and prosperity of nations ultima...
# 4  It is with peculiar satisfaction that I meet t...

# %% [markdown]
# Dropping indeces 208,801, and 814 as they were not appropriately transformed upon import

# %%
speeches.drop([208,801,814],inplace=True)

# %%
speeches['date']=pd.to_datetime(speeches['date'])

# %%
speeches.set_index('date',inplace=True)

# %%
speeches=speeches.loc['1969':,:]

# %%
speeches['text']=speeches['text'].str.lower()

# %% [markdown]
# Loading stopwords from NLTK

# %%
from nltk.corpus import stopwords

# %%
from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_tags,strip_punctuation,strip_numeric,stem_text
from gensim.parsing.preprocessing import strip_multiple_whitespaces,strip_non_alphanum,remove_stopwords,strip_short
import pattern
import nltk

# %%
Filtering=[lambda x: x.lower(),strip_multiple_whitespaces,
          strip_numeric,
          remove_stopwords,
          strip_short]

# %%
def preprocess(text):
    result=[]
    for token in preprocess_string(text,Filtering):
        result.append(token)
    return result
speeches['processed_speech']=speeches['text'].map(preprocess)

# %%
lemmatizer=nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    return[lemmatizer.lemmatize(w) for w in text]

# %%
speeches['processed_speech']=speeches.processed_speech.apply(lemmatize_text)

# %%
speeches['bigrams']=speeches.processed_speech.apply(lambda row: list(nltk.ngrams(row,2)))

# %%
from gensim import corpora,models,similarities
dictionary=corpora.Dictionary(speeches.processed_speech)

# %% [markdown]
# Creating the corpus of documents. Doc2Bow counts the number of occurences of each distinct word and converts the word to an integer word ID. Returns a sparse vector

# %%
corpus=[dictionary.doc2bow(text) for text in speeches.processed_speech]

# %% [markdown]
# Building a TF-IDF Model (Term Frequency Inverse Document Frequency)

# %%
tfidf=models.TfidfModel(corpus)
transformed_tfidf = tfidf[corpus]

# %% [markdown]
# LDA (Latent Dirichlet Allocation) on TF-IDF

# %%
num_topics=5
# %time lda = models.LdaModel(transformed_tfidf,id2word=dictionary,num_topics=num_topics,passes=4,alpha=[.01]*num_topics,eta=[.01]*len(dictionary.keys()))
# Out:
# Wall time: 11.6 s

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.005*"<applause.>" + 0.003*"soviet" + 0.002*"palestinian" + 0.001*"arm" + 0.001*"israel" + 0.001*"peace" + 0.001*"strategic" + 0.001*"missile" + 0.001*"israeli" + 0.001*"nuclear"'),
#  (1,
#   '0.001*"kosovo" + 0.001*"polish" + 0.001*"robert" + 0.001*"assad" + 0.001*"sotomayor" + 0.001*"embryonic" + 0.001*"grace." + 0.001*"qadhafi" + 0.001*"pinckney" + 0.001*"christmas"'),
#  (2,
#   '0.001*"lilly" + 0.001*"transportation." + 0.001*"lehrer." + 0.001*"nafta" + 0.001*"newman:" + 0.001*"ada" + 0.001*"dole:" + 0.001*"><president" + 0.001*"><mr." + 0.001*"guerrilla"'),
#  (3,
#   '0.001*"saddam" + 0.001*"coalition" + 0.001*"somali" + 0.001*"rescue" + 0.001*"lebanon" + 0.001*"lebanese" + 0.001*"bosnia" + 0.001*"kuwait" + 0.001*"somalia" + 0.001*"iraq"'),
#  (4,
#   '0.002*"tax" + 0.001*"health" + 0.001*"<applause.>" + 0.001*"energy" + 0.001*"federal" + 0.001*"think" + 0.001*"oil" + 0.001*"congress" + 0.001*"iraqi" + 0.001*"budget"')]

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis=pyLDAvis.gensim.prepare(lda,corpus,dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.174680  0.012121       1        1  90.984711
# 0      0.023048 -0.094689       2        1   8.584785
# 2      0.049509  0.025603       3        1   0.191746
# 3      0.064451  0.033087       4        1   0.146449
# 1      0.037672  0.023878       5        1   0.092315, topic_info=              Term        Freq       Total Category  logprob  loglift
# 24797  <applause.>  739.000000  739.000000  Default  30.0000  30.0000
# 2638           tax  919.000000  919.000000  Default  29.0000  29.0000
# 7391         iraqi  516.000000  516.000000  Default  28.0000  28.0000
# 3815          iraq  468.000000  468.000000  Default  27.0000  27.0000
# 7437        saddam  229.000000  229.000000  Default  26.0000  26.0000
# ...            ...         ...         ...      ...      ...      ...
# 7255      platform    0.168086   39.503487   Topic5  -7.8141   1.5281
# 24797  <applause.>    0.229688  739.718872   Topic5  -7.5018  -1.0896
# 4503        soviet    0.208682  379.319763   Topic5  -7.5977  -0.5176
# 2638           tax    0.192101  919.504517   Topic5  -7.6805  -1.4858
# 3182      chemical    0.159352  140.562637   Topic5  -7.8674   0.2054
#
# [309 rows x 6 columns], token_table=       Topic      Freq                 Term
# term
# 24797      1  0.715137          <applause.>
# 24797      2  0.285244          <applause.>
# 24993      1  0.166287       <applause.>and
# 24993      2  0.831434       <applause.>and
# 41796      1  0.707044  <em>challenger</em>
# ...      ...       ...                  ...
# 4800       1  0.158956                 west
# 4800       2  0.854390                 west
# 2838       1  0.217431              western
# 2838       2  0.797246              western
# 29987      1  0.872217             years.it
#
# [494 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 1, 3, 4, 2])

# %%
count = 1
for doc in speeches['processed_speech']:
    vec=dictionary.doc2bow(doc)
    print("Speech # ",count, lda[vec])
    count=count+1
# Out:
# Speech #  1 [(0, 0.09220263), (4, 0.9077882)]
# Speech #  2 [(0, 0.085106485), (4, 0.91488796)]
# Speech #  3 [(0, 0.056308724), (4, 0.9436487)]
# Speech #  4 [(0, 0.08491038), (4, 0.91506773)]
# Speech #  5 [(0, 0.09722316), (3, 0.06288318), (4, 0.8398279)]
# Speech #  6 [(0, 0.1712791), (4, 0.8286845)]
# Speech #  7 [(0, 0.054753207), (4, 0.94522953)]
# Speech #  8 [(0, 0.043131392), (4, 0.9568473)]
# Speech #  9 [(0, 0.05755133), (2, 0.03200858), (4, 0.91040677)]
# Speech #  10 [(0, 0.07532647), (4, 0.9246206)]
# Speech #  11 [(0, 0.06995547), (4, 0.9260086)]
# Speech #  12 [(0, 0.065581776), (4, 0.9325721)]
# Speech #  13 [(0, 0.035844125), (4, 0.9640786)]
# Speech #  14 [(0, 0.08042852), (3, 0.03599217), (4, 0.8835419)]
# Speech #  15 [(0, 0.055964574), (4, 0.94401467)]
# Speech #  16 [(0, 0.12057253), (3, 0.06557165), (4, 0.8137839)]
# Speech #  17 [(0, 0.1248989), (4, 0.8726446)]
# Speech #  18 [(0, 0.105721906), (4, 0.89113814)]
# Speech #  19 [(0, 0.09463854), (4, 0.90534437)]
# Speech #  20 [(0, 0.08110251), (4, 0.91888106)]
# Speech #  21 [(0, 0.06293379), (2, 0.024191348), (4, 0.9128714)]
# Speech #  22 [(0, 0.06741533), (3, 0.051729973), (4, 0.88080484)]
# Speech #  23 [(0, 0.104021385), (4, 0.8959555)]
# Speech #  24 [(0, 0.09943691), (4, 0.9005342)]
# Speech #  25 [(0, 0.06311569), (4, 0.93684095)]
# Speech #  26 [(0, 0.04432187), (4, 0.9556713)]
# Speech #  27 [(0, 0.09710848), (4, 0.90288454)]
# Speech #  28 [(0, 0.047496155), (4, 0.9524967)]
# Speech #  29 [(0, 0.036990345), (4, 0.962923)]
# Speech #  30 [(0, 0.033057638), (4, 0.9669171)]
# Speech #  31 [(0, 0.0991081), (4, 0.9008734)]
# Speech #  32 [(0, 0.012842367), (4, 0.9871229)]
# Speech #  33 [(0, 0.13488673), (4, 0.8650841)]
# Speech #  34 [(0, 0.03451659), (4, 0.96544904)]
# Speech #  35 [(0, 0.025924573), (4, 0.9739543)]
# Speech #  36 [(0, 0.3462866), (4, 0.6536016)]
# Speech #  37 [(0, 0.0500274), (4, 0.9499552)]
# Speech #  38 [(0, 0.051024914), (4, 0.9489502)]
# Speech #  39 [(0, 0.07816696), (1, 0.04116317), (4, 0.8806074)]
# Speech #  40 [(0, 0.07927099), (4, 0.9207053)]
# Speech #  41 [(0, 0.057304744), (4, 0.94266975)]
# Speech #  42 [(0, 0.14987794), (4, 0.85009944)]
# Speech #  43 [(0, 0.15867338), (4, 0.8412654)]
# Speech #  44 [(0, 0.14528677), (3, 0.07080569), (4, 0.7838265)]
# Speech #  45 [(0, 0.07031284), (4, 0.9296692)]
# Speech #  46 [(0, 0.065389976), (4, 0.9346042)]
# Speech #  47 [(0, 0.06695702), (4, 0.93300396)]
# Speech #  48 [(0, 0.040071543), (4, 0.9598689)]
# Speech #  49 [(0, 0.037121788), (4, 0.96279484)]
# Speech #  50 [(4, 0.98441344)]
# Speech #  51 [(0, 0.022176169), (4, 0.97780764)]
# Speech #  52 [(0, 0.026614139), (4, 0.97337365)]
# Speech #  53 [(0, 0.054283608), (1, 0.06438661), (4, 0.88126886)]
# Speech #  54 [(0, 0.19563091), (4, 0.80428404)]
# Speech #  55 [(0, 0.055658244), (4, 0.94432956)]
# Speech #  56 [(0, 0.040775128), (3, 0.061509997), (4, 0.89768296)]
# Speech #  57 [(0, 0.069615245), (4, 0.9303628)]
# Speech #  58 [(0, 0.054438964), (2, 0.01212198), (4, 0.933416)]
# Speech #  59 [(0, 0.05283091), (4, 0.9470866)]
# Speech #  60 [(0, 0.056951057), (4, 0.94303805)]
# Speech #  61 [(0, 0.043959312), (3, 0.04624686), (4, 0.90971303)]
# Speech #  62 [(0, 0.059581056), (4, 0.9404098)]
# Speech #  63 [(0, 0.15569848), (4, 0.8442089)]
# Speech #  64 [(0, 0.033120528), (4, 0.96686614)]
# Speech #  65 [(0, 0.04074343), (4, 0.9592373)]
# Speech #  66 [(0, 0.09290276), (3, 0.026256528), (4, 0.8808209)]
# Speech #  67 [(0, 0.15705408), (4, 0.8429151)]
# Speech #  68 [(0, 0.03149986), (4, 0.96848714)]
# Speech #  69 [(0, 0.03220215), (2, 0.015977422), (4, 0.95178837)]
# Speech #  70 [(0, 0.058180444), (4, 0.94180715)]
# Speech #  71 [(0, 0.023265246), (4, 0.9767055)]
# Speech #  72 [(0, 0.04890967), (2, 0.036878835), (4, 0.9142084)]
# Speech #  73 [(0, 0.05604038), (4, 0.9439202)]
# Speech #  74 [(0, 0.04177091), (4, 0.9582166)]
# Speech #  75 [(0, 0.19431268), (4, 0.8056154)]
# Speech #  76 [(4, 0.9998909)]
# Speech #  77 [(0, 0.049911045), (4, 0.9500776)]
# Speech #  78 [(0, 0.14756855), (4, 0.8523812)]
# Speech #  79 [(0, 0.077066846), (3, 0.039838873), (4, 0.8830648)]
# Speech #  80 [(0, 0.19785522), (4, 0.8019742)]
# Speech #  81 [(0, 0.111509465), (1, 0.048248358), (4, 0.8350045)]
# Speech #  82 [(0, 0.055725947), (1, 0.026112666), (4, 0.91812766)]
# Speech #  83 [(0, 0.035918616), (4, 0.96407056)]
# Speech #  84 [(0, 0.037762146), (4, 0.96222895)]
# Speech #  85 [(0, 0.03287676), (4, 0.9651207)]
# Speech #  86 [(0, 0.033286143), (4, 0.96661896)]
# Speech #  87 [(0, 0.02030107), (4, 0.9795867)]
# Speech #  88 [(0, 0.075279854), (3, 0.05031799), (4, 0.87429565)]
# Speech #  89 [(0, 0.038542118), (4, 0.96143705)]
# Speech #  90 [(0, 0.04805773), (4, 0.9519036)]
# Speech #  91 [(0, 0.05156779), (4, 0.9484122)]
# Speech #  92 [(0, 0.10569083), (4, 0.8942951)]
# Speech #  93 [(0, 0.09395877), (4, 0.9060028)]
# Speech #  94 [(0, 0.033338506), (4, 0.96659863)]
# Speech #  95 [(0, 0.086017095), (4, 0.9139497)]
# Speech #  96 [(0, 0.046151295), (4, 0.9538125)]
# Speech #  97 [(0, 0.049351405), (4, 0.9506327)]
# Speech #  98 [(0, 0.035142686), (4, 0.9648263)]
# Speech #  99 [(0, 0.06520065), (4, 0.93478227)]
# Speech #  100 [(0, 0.2747425), (4, 0.71980405)]
# Speech #  101 [(0, 0.026571512), (4, 0.97337025)]
# Speech #  102 [(0, 0.016125744), (4, 0.9838013)]
# Speech #  103 [(0, 0.040013444), (4, 0.95988935)]
# Speech #  104 [(0, 0.03455533), (4, 0.9653602)]
# Speech #  105 [(0, 0.23927128), (4, 0.76059395)]
# Speech #  106 [(0, 0.1258616), (4, 0.873049)]
# Speech #  107 [(0, 0.026167361), (4, 0.9737966)]
# Speech #  108 [(0, 0.07901326), (4, 0.9209657)]
# Speech #  109 [(0, 0.16254471), (4, 0.83742714)]
# Speech #  110 [(0, 0.071211725), (4, 0.92873245)]
# Speech #  111 [(0, 0.13632098), (4, 0.8586941)]
# Speech #  112 [(4, 0.9955643)]
# Speech #  113 [(0, 0.076439925), (4, 0.9235443)]
# Speech #  114 [(0, 0.13227741), (4, 0.8676763)]
# Speech #  115 [(0, 0.07413668), (3, 0.05234227), (4, 0.8734325)]
# Speech #  116 [(0, 0.16468783), (4, 0.83528954)]
# Speech #  117 [(0, 0.11665435), (4, 0.8833152)]
# Speech #  118 [(0, 0.12023544), (4, 0.8797315)]
# Speech #  119 [(0, 0.07684347), (4, 0.92314094)]
# Speech #  120 [(0, 0.15120618), (4, 0.848763)]
# Speech #  121 [(0, 0.03222504), (4, 0.9677313)]
# Speech #  122 [(0, 0.09925269), (4, 0.9007319)]
# Speech #  123 [(0, 0.09291995), (4, 0.90706396)]
# Speech #  124 [(0, 0.042065825), (4, 0.95786977)]
# Speech #  125 [(0, 0.14208959), (4, 0.8578841)]
# Speech #  126 [(0, 0.15020622), (4, 0.84975386)]
# Speech #  127 [(0, 0.085984), (4, 0.9140006)]
# Speech #  128 [(0, 0.24185818), (1, 0.023371184), (4, 0.7347368)]
# Speech #  129 [(0, 0.117759526), (4, 0.88221365)]
# Speech #  130 [(0, 0.14183898), (4, 0.8581383)]
# Speech #  131 [(0, 0.0899511), (4, 0.91003335)]
# Speech #  132 [(0, 0.0703394), (4, 0.92964685)]
# Speech #  133 [(0, 0.045251135), (4, 0.9546319)]
# Speech #  134 [(0, 0.087978), (4, 0.9119961)]
# Speech #  135 [(0, 0.047606815), (4, 0.9523673)]
# Speech #  136 [(0, 0.052172836), (3, 0.09974732), (4, 0.84802943)]
# Speech #  137 [(0, 0.0749076), (4, 0.92507917)]
# Speech #  138 [(0, 0.086478576), (4, 0.91347605)]
# Speech #  139 [(0, 0.035738464), (4, 0.9642503)]
# Speech #  140 [(0, 0.14692844), (4, 0.8530479)]
# Speech #  141 [(0, 0.03933662), (4, 0.9606127)]
# Speech #  142 [(0, 0.0749025), (4, 0.92507714)]
# Speech #  143 [(0, 0.051566344), (4, 0.9484143)]
# Speech #  144 [(0, 0.07496143), (4, 0.91899085)]
# Speech #  145 [(0, 0.04040774), (4, 0.9595729)]
# Speech #  146 [(0, 0.08547612), (4, 0.9144883)]
# Speech #  147 [(0, 0.54047483), (4, 0.45928726)]
# Speech #  148 [(0, 0.048780296), (4, 0.951198)]
# Speech #  149 [(0, 0.19784626), (4, 0.8021182)]
# Speech #  150 [(0, 0.07749559), (4, 0.92246664)]
# Speech #  151 [(0, 0.07069209), (3, 0.021738684), (4, 0.9074772)]
# Speech #  152 [(0, 0.05306257), (2, 0.027753087), (4, 0.91908294)]
# Speech #  153 [(0, 0.054310393), (4, 0.94563466)]
# Speech #  154 [(0, 0.13327049), (4, 0.8666564)]
# Speech #  155 [(0, 0.062274195), (4, 0.9376979)]
# Speech #  156 [(0, 0.08830924), (4, 0.9116567)]
# Speech #  157 [(0, 0.060732204), (4, 0.93924916)]
# Speech #  158 [(0, 0.060926836), (4, 0.9390559)]
# Speech #  159 [(0, 0.15098222), (4, 0.84899473)]
# Speech #  160 [(0, 0.048490535), (4, 0.95145273)]
# Speech #  161 [(0, 0.05281794), (4, 0.9471183)]
# Speech #  162 [(0, 0.060632482), (4, 0.93931437)]
# Speech #  163 [(0, 0.07491323), (4, 0.92504245)]
# Speech #  164 [(0, 0.052373003), (4, 0.9476081)]
# Speech #  165 [(0, 0.042566), (2, 0.041926384), (4, 0.91543573)]
# Speech #  166 [(0, 0.0708429), (1, 0.04943487), (4, 0.87968045)]
# Speech #  167 [(0, 0.11756272), (4, 0.8824064)]
# Speech #  168 [(0, 0.040906474), (4, 0.95907986)]
# Speech #  169 [(0, 0.1430069), (4, 0.85697806)]
# Speech #  170 [(0, 0.12541023), (4, 0.8745704)]
# Speech #  171 [(0, 0.07255929), (4, 0.9274293)]
# Speech #  172 [(0, 0.1192241), (4, 0.880753)]
# Speech #  173 [(0, 0.065055095), (4, 0.93492895)]
# Speech #  174 [(0, 0.113093615), (4, 0.8868811)]
# Speech #  175 [(0, 0.078848936), (4, 0.9211341)]
# Speech #  176 [(0, 0.077267274), (3, 0.029904094), (4, 0.8928111)]
# Speech #  177 [(0, 0.08818747), (4, 0.9117927)]
# Speech #  178 [(0, 0.094323866), (4, 0.9056443)]
# Speech #  179 [(0, 0.12610267), (4, 0.8738656)]
# Speech #  180 [(0, 0.11703788), (4, 0.8829404)]
# Speech #  181 [(0, 0.07033478), (4, 0.9296549)]
# Speech #  182 [(0, 0.18269372), (4, 0.8172684)]
# Speech #  183 [(0, 0.057865888), (4, 0.9420696)]
# Speech #  184 [(0, 0.13511084), (4, 0.86400276)]
# Speech #  185 [(0, 0.09584698), (4, 0.904141)]
# Speech #  186 [(0, 0.21651901), (4, 0.78340495)]
# Speech #  187 [(0, 0.116981395), (4, 0.88299674)]
# Speech #  188 [(0, 0.11379227), (4, 0.8861897)]
# Speech #  189 [(0, 0.09649535), (4, 0.90349364)]
# Speech #  190 [(0, 0.076468386), (4, 0.9234691)]
# Speech #  191 [(0, 0.1631299), (4, 0.8368313)]
# Speech #  192 [(0, 0.08264566), (4, 0.9173105)]
# Speech #  193 [(0, 0.14502914), (4, 0.85494375)]
# Speech #  194 [(0, 0.06635763), (4, 0.93363136)]
# Speech #  195 [(0, 0.12377502), (4, 0.8762089)]
# Speech #  196 [(0, 0.17972891), (4, 0.8202551)]
# Speech #  197 [(0, 0.073423326), (4, 0.9265496)]
# Speech #  198 [(0, 0.08431274), (4, 0.9156401)]
# Speech #  199 [(0, 0.078917794), (4, 0.92106456)]
# Speech #  200 [(0, 0.117919505), (1, 0.026619326), (4, 0.85543513)]
# Speech #  201 [(0, 0.06762414), (4, 0.9323636)]
# Speech #  202 [(0, 0.078611806), (4, 0.92137635)]
# Speech #  203 [(0, 0.042673554), (4, 0.957287)]
# Speech #  204 [(0, 0.084230915), (4, 0.91575736)]
# Speech #  205 [(0, 0.09885958), (1, 0.05025308), (4, 0.8508645)]
# Speech #  206 [(0, 0.06893174), (4, 0.9310422)]
# Speech #  207 [(0, 0.062048543), (4, 0.93489844)]
# Speech #  208 [(0, 0.10280719), (4, 0.89717925)]
# Speech #  209 [(0, 0.13754584), (4, 0.8624367)]
# Speech #  210 [(0, 0.0918994), (4, 0.90808046)]
# Speech #  211 [(0, 0.0810779), (4, 0.9187919)]
# Speech #  212 [(0, 0.046801537), (4, 0.953173)]
# Speech #  213 [(0, 0.054642882), (4, 0.94533694)]
# Speech #  214 [(0, 0.13062955), (4, 0.8693304)]
# Speech #  215 [(0, 0.07395253), (4, 0.9260114)]
# Speech #  216 [(0, 0.06749161), (4, 0.93247557)]
# Speech #  217 [(0, 0.052127056), (4, 0.94784886)]
# Speech #  218 [(0, 0.06450717), (4, 0.93546736)]
# Speech #  219 [(0, 0.0834809), (2, 0.046568427), (4, 0.8699233)]
# Speech #  220 [(0, 0.2541317), (4, 0.7458426)]
# Speech #  221 [(0, 0.058497787), (1, 0.06743015), (4, 0.8740437)]
# Speech #  222 [(0, 0.07788005), (4, 0.92210394)]
# Speech #  223 [(0, 0.12113644), (4, 0.8788418)]
# Speech #  224 [(0, 0.18592648), (4, 0.81404847)]
# Speech #  225 [(0, 0.17172833), (4, 0.82824695)]
# Speech #  226 [(0, 0.035764925), (4, 0.96420705)]
# Speech #  227 [(0, 0.28961435), (4, 0.70666426)]
# Speech #  228 [(0, 0.1547146), (3, 0.060777765), (4, 0.7844597)]
# Speech #  229 [(0, 0.06496437), (4, 0.93501747)]
# Speech #  230 [(0, 0.07490695), (4, 0.9250783)]
# Speech #  231 [(0, 0.11412358), (4, 0.88585234)]
# Speech #  232 [(0, 0.17629132), (4, 0.8236895)]
# Speech #  233 [(0, 0.2589151), (4, 0.7410479)]
# Speech #  234 [(0, 0.13584854), (3, 0.026525104), (4, 0.8376182)]
# Speech #  235 [(0, 0.10869811), (2, 0.03527207), (4, 0.856016)]
# Speech #  236 [(0, 0.041587494), (3, 0.07698418), (4, 0.88136)]
# Speech #  237 [(0, 0.09391502), (3, 0.047131196), (4, 0.85889435)]
# Speech #  238 [(0, 0.16915737), (4, 0.8307358)]
# Speech #  239 [(0, 0.051159777), (4, 0.94879794)]
# Speech #  240 [(0, 0.06310644), (4, 0.93600696)]
# Speech #  241 [(0, 0.058563326), (1, 0.020808857), (4, 0.9205954)]
# Speech #  242 [(0, 0.12659), (4, 0.87334937)]
# Speech #  243 [(0, 0.0992469), (4, 0.9007351)]
# Speech #  244 [(0, 0.123928085), (2, 0.02552454), (4, 0.8492802)]
# Speech #  245 [(0, 0.069692224), (4, 0.9302742)]
# Speech #  246 [(0, 0.07054559), (4, 0.92943543)]
# Speech #  247 [(0, 0.035381846), (4, 0.964527)]
# Speech #  248 [(0, 0.25626773), (4, 0.74369746)]
# Speech #  249 [(0, 0.055848233), (3, 0.07936657), (4, 0.86469257)]
# Speech #  250 [(0, 0.09762559), (4, 0.9023504)]
# Speech #  251 [(0, 0.11640205), (1, 0.08684661), (4, 0.7966897)]
# Speech #  252 [(0, 0.041402943), (4, 0.95856625)]
# Speech #  253 [(0, 0.25641766), (4, 0.74355334)]
# Speech #  254 [(0, 0.017072631), (4, 0.98286784)]
# Speech #  255 [(0, 0.07524646), (4, 0.92473084)]
# Speech #  256 [(0, 0.13948846), (4, 0.86046547)]
# Speech #  257 [(0, 0.17522486), (4, 0.8246687)]
# Speech #  258 [(0, 0.27147546), (4, 0.72849345)]
# Speech #  259 [(0, 0.08899663), (4, 0.9109864)]
# Speech #  260 [(0, 0.09393621), (4, 0.9060492)]
# Speech #  261 [(0, 0.09389078), (4, 0.90608853)]
# Speech #  262 [(0, 0.14258564), (4, 0.8573966)]
# Speech #  263 [(4, 0.9996466)]
# Speech #  264 [(0, 0.08409541), (4, 0.9158912)]
# Speech #  265 [(0, 0.07034957), (4, 0.9296215)]

# %%
t=0
for i in lda.show_topics(num_topics=num_topics, num_words=5, log=False, formatted=True):
    print ("Topic # ", t , i)
    t = t + 1
# Out:
# Topic #  0 (0, '0.005*"<applause.>" + 0.003*"soviet" + 0.002*"palestinian" + 0.001*"arm" + 0.001*"israel"')
# Topic #  1 (1, '0.001*"kosovo" + 0.001*"polish" + 0.001*"robert" + 0.001*"assad" + 0.001*"sotomayor"')
# Topic #  2 (2, '0.001*"lilly" + 0.001*"transportation." + 0.001*"lehrer." + 0.001*"nafta" + 0.001*"newman:"')
# Topic #  3 (3, '0.001*"saddam" + 0.001*"coalition" + 0.001*"somali" + 0.001*"rescue" + 0.001*"lebanon"')
# Topic #  4 (4, '0.002*"tax" + 0.001*"health" + 0.001*"<applause.>" + 0.001*"energy" + 0.001*"federal"')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
for t in range(lda.num_topics):
    plt.figure()
    plt.imshow(WordCloud().fit_words(dict(lda.show_topic(t,50))))
    plt.axis("off")
    plt.title("Topic #" + str(t))
    plt.show()

# %%
topics = [lda[corpus[i]] for i in range(len(speeches))]

def topics_document_to_dataframe(topics_document, num_topics):
    res = pd.DataFrame(columns=range(num_topics))
    for topic_weight in topics_document:
        res.loc[0, topic_weight[0]] = topic_weight[1]
    return res
document_topic=\
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics]) \
  .reset_index(drop=True).fillna(0)

# %%
import seaborn as sns
sns.heatmap(document_topic.loc[document_topic.idxmax(axis=1).sort_values().index])
plt.xlabel('Topic')
plt.ylabel('Speech')
# Out:
# Text(33.0, 0.5, 'Speech')

# %%
sns.set(rc={'figure.figsize':(10,5)})
document_topic.idxmax(axis=1).value_counts().plot.bar(color='lightblue')
