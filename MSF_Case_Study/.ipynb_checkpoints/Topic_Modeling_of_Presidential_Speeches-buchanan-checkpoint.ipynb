# %%
import pandas as pd
import numpy as np
import scipy as sp
import gensim
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
# %matplotlib inline

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models, matutils

# %% [markdown]
# Importing all Presidential speeches and appending them to a dataframe

# %%
from os import path
from pathlib import Path
import os
import glob
from collections import defaultdict
root=r'C:\Users\hartg\Desktop\Professional_Projects\Professional-Projects\MSF_Case_Study\Corpus of Presential Speeches\bharrison'
files=os.listdir(root)

#load speeches into a list

docs=list()
for file in files:
    with open(path.join(root,file),'r',encoding='utf-8') as fd:
        txt=fd.read()
        docs.append(txt)

# %% [markdown]
# Function that "cleans" the speeches. Re (regular expression) replaces special characters with, in this case, nothing. This will remove the <title=> characters, etc

# %%
import re
def clean(doc):
    doc = re.sub(r'[^\w\s]*','',doc)
    doc = re.sub(r'[\s]+', ' ', doc)
    doc = doc.lower().strip()
    return doc

# %% [markdown]
# clean the documents associated with the presidential speeches

# %%
clean_docs=list()
for doc in docs:
    doc = clean(doc)
    clean_docs.append(doc)

# %%
speeches_df=pd.DataFrame(docs)
speeches_df.columns=['text']

# %%
speeches_df.head()
# Out:
#                                                 text
# 0  <title="First Annual Message">\n<date="Decembe...
# 1  <title="Statement on the Johnstown Flood">\n<d...
# 2  <title="Commemoration of the Centennial of Was...
# 3  <title="Inaugural Address">\n<date="March 4, 1...
# 4  <title="Address Honoring President Garfield">\...

# %%
new_df=speeches_df['text'].str.split("=",n=1,expand=True)
new_df.columns=['title_bad','title_actual']
new_df.head()
# Out:
#   title_bad                                       title_actual
# 0    <title  "First Annual Message">\n<date="December 3, 18...
# 1    <title  "Statement on the Johnstown Flood">\n<date="Ju...
# 2    <title  "Commemoration of the Centennial of Washington...
# 3    <title  "Inaugural Address">\n<date="March 4, 1889">\n...
# 4    <title  "Address Honoring President Garfield">\n<date=...

# %%
new_df2=new_df['title_actual'].str.split("=",n=1,expand=True)
new_df2.columns=['title','date_and_text']
new_df2.head()
# Out:
#                                                title  \
# 0                     "First Annual Message">\n<date
# 1         "Statement on the Johnstown Flood">\n<date
# 2  "Commemoration of the Centennial of Washington...
# 3                        "Inaugural Address">\n<date
# 4      "Address Honoring President Garfield">\n<date
#
#                                        date_and_text
# 0  "December 3, 1889">\nTo the Senate and House o...
# 1  "June 4, 1889">\nMy Fellow-Citizens:\nEveryone...
# 2  "April 4, 1889">\nBy the President of the Unit...
# 3  "March 4, 1889">\n\nFellow-Citizens:\n\nThere ...
# 4  "May 30, 1890">\nMr. Chairman and fellow-citiz...

# %%
new_df3=new_df2['date_and_text'].str.split(">",n=1,expand=True)
new_df3.columns=['date','text']

# %%
new_df3.head()
# Out:
#                  date                                               text
# 0  "December 3, 1889"  \nTo the Senate and House of Representatives: ...
# 1      "June 4, 1889"  \nMy Fellow-Citizens:\nEveryone here to-day is...
# 2     "April 4, 1889"  \nBy the President of the United States of Ame...
# 3     "March 4, 1889"  \n\nFellow-Citizens:\n\nThere is no constituti...
# 4      "May 30, 1890"  \nMr. Chairman and fellow-citizens:\nI thank y...

# %%
speeches=pd.merge(new_df2,new_df3,left_index=True,right_index=True)

# %%
speeches.head()
# Out:
#                                                title  \
# 0                     "First Annual Message">\n<date
# 1         "Statement on the Johnstown Flood">\n<date
# 2  "Commemoration of the Centennial of Washington...
# 3                        "Inaugural Address">\n<date
# 4      "Address Honoring President Garfield">\n<date
#
#                                        date_and_text                date  \
# 0  "December 3, 1889">\nTo the Senate and House o...  "December 3, 1889"
# 1  "June 4, 1889">\nMy Fellow-Citizens:\nEveryone...      "June 4, 1889"
# 2  "April 4, 1889">\nBy the President of the Unit...     "April 4, 1889"
# 3  "March 4, 1889">\n\nFellow-Citizens:\n\nThere ...     "March 4, 1889"
# 4  "May 30, 1890">\nMr. Chairman and fellow-citiz...      "May 30, 1890"
#
#                                                 text
# 0  \nTo the Senate and House of Representatives: ...
# 1  \nMy Fellow-Citizens:\nEveryone here to-day is...
# 2  \nBy the President of the United States of Ame...
# 3  \n\nFellow-Citizens:\n\nThere is no constituti...
# 4  \nMr. Chairman and fellow-citizens:\nI thank y...

# %%
speeches.drop(['date_and_text'],axis=1,inplace=True)

# %%
speeches['title']=speeches.title.str.replace('>\n<date','',regex=True)
speeches.head()
# Out:
#                                                title                date  \
# 0                             "First Annual Message"  "December 3, 1889"
# 1                 "Statement on the Johnstown Flood"      "June 4, 1889"
# 2  "Commemoration of the Centennial of Washington...     "April 4, 1889"
# 3                                "Inaugural Address"     "March 4, 1889"
# 4              "Address Honoring President Garfield"      "May 30, 1890"
#
#                                                 text
# 0  \nTo the Senate and House of Representatives: ...
# 1  \nMy Fellow-Citizens:\nEveryone here to-day is...
# 2  \nBy the President of the United States of Ame...
# 3  \n\nFellow-Citizens:\n\nThere is no constituti...
# 4  \nMr. Chairman and fellow-citizens:\nI thank y...

# %%
speeches['date']=speeches.date.str.replace('"','',regex=True)
speeches.head()
# Out:
#                                                title              date  \
# 0                             "First Annual Message"  December 3, 1889
# 1                 "Statement on the Johnstown Flood"      June 4, 1889
# 2  "Commemoration of the Centennial of Washington...     April 4, 1889
# 3                                "Inaugural Address"     March 4, 1889
# 4              "Address Honoring President Garfield"      May 30, 1890
#
#                                                 text
# 0  \nTo the Senate and House of Representatives: ...
# 1  \nMy Fellow-Citizens:\nEveryone here to-day is...
# 2  \nBy the President of the United States of Ame...
# 3  \n\nFellow-Citizens:\n\nThere is no constituti...
# 4  \nMr. Chairman and fellow-citizens:\nI thank y...

# %%
speeches['text']=speeches.text.str.replace("\n",'',regex=True)
speeches.head()
# Out:
#                                                title              date  \
# 0                             "First Annual Message"  December 3, 1889
# 1                 "Statement on the Johnstown Flood"      June 4, 1889
# 2  "Commemoration of the Centennial of Washington...     April 4, 1889
# 3                                "Inaugural Address"     March 4, 1889
# 4              "Address Honoring President Garfield"      May 30, 1890
#
#                                                 text
# 0  To the Senate and House of Representatives: Th...
# 1  My Fellow-Citizens:Everyone here to-day is dis...
# 2  By the President of the United States of Ameri...
# 3  Fellow-Citizens:There is no constitutional or ...
# 4  Mr. Chairman and fellow-citizens:I thank you m...

# %% [markdown]
# Dropping indeces 208,801, and 814 as they were not appropriately transformed upon import

# %%
speeches['date']=pd.to_datetime(speeches['date'])

# %%
speeches['text']=speeches['text'].str.lower()

# %% [markdown]
# Loading stopwords from NLTK

# %%
from nltk.corpus import stopwords

# %%
from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_tags,strip_punctuation,strip_numeric,stem_text
from gensim.parsing.preprocessing import strip_multiple_whitespaces,strip_non_alphanum,remove_stopwords,strip_short
import pattern
import nltk

# %%
Filtering=[lambda x: x.lower(),strip_multiple_whitespaces,
          strip_numeric,
          remove_stopwords,
          strip_short]

# %%
def preprocess(text):
    result=[]
    for token in preprocess_string(text,Filtering):
        result.append(token)
    return result
speeches['processed_speech']=speeches['text'].map(preprocess)

# %%
lemmatizer=nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    return[lemmatizer.lemmatize(w) for w in text]

# %%
speeches['processed_speech']=speeches.processed_speech.apply(lemmatize_text)

# %%
speeches['bigrams']=speeches.processed_speech.apply(lambda row: list(nltk.ngrams(row,2)))

# %%
from gensim import corpora,models,similarities
dictionary=corpora.Dictionary(speeches.processed_speech)

# %% [markdown]
# Creating the corpus of documents. Doc2Bow counts the number of occurences of each distinct word and converts the word to an integer word ID. Returns a sparse vector

# %%
corpus=[dictionary.doc2bow(text) for text in speeches.processed_speech]

# %% [markdown]
# Building a TF-IDF Model (Term Frequency Inverse Document Frequency)

# %%
tfidf=models.TfidfModel(corpus)
transformed_tfidf = tfidf[corpus]

# %% [markdown]
# LDA (Latent Dirichlet Allocation) on TF-IDF

# %%
num_topics=5
# %time lda = models.LdaModel(transformed_tfidf,id2word=dictionary,num_topics=num_topics,passes=4,alpha=[.01]*num_topics,eta=[.01]*len(dictionary.keys()))
# Out:
# Wall time: 761 ms

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.005*"year" + 0.004*"mr." + 0.004*"increase" + 0.004*"work" + 0.004*"january" + 0.004*"$,," + 0.003*"silver" + 0.003*"$,,," + 0.003*"blaine," + 0.003*"minister"'),
#  (1,
#   '0.000*"year" + 0.000*"law" + 0.000*"government" + 0.000*"silver" + 0.000*"indian" + 0.000*"$,," + 0.000*"land" + 0.000*"use" + 0.000*"result" + 0.000*"increase"'),
#  (2,
#   '0.004*"hawaiian" + 0.004*"democratic" + 0.003*"police" + 0.003*"chilean" + 0.003*"government" + 0.003*"annexation" + 0.002*"islands." + 0.002*"queen" + 0.002*"captain" + 0.002*"monarchy"'),
#  (3,
#   '0.002*"latin-american" + 0.002*"to-day" + 0.002*"treaty" + 0.002*"access" + 0.002*"markets," + 0.002*"suggest," + 0.002*"williamsport," + 0.002*"brotherhood" + 0.002*"horror" + 0.002*"doubt,"'),
#  (4,
#   '0.005*"indian" + 0.005*"law" + 0.004*"american" + 0.004*"land" + 0.003*"public" + 0.003*"duty" + 0.003*"new" + 0.003*"united" + 0.003*"act" + 0.003*"great"')]

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis=pyLDAvis.gensim.prepare(lda,corpus,dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.074808 -0.001575       1        1  61.971123
# 0      0.026063 -0.023812       2        1  27.255695
# 2      0.017564  0.002669       3        1   8.417435
# 3      0.021498  0.019967       4        1   2.353582
# 1      0.009683  0.002751       5        1   0.002166, topic_info=           Term        Freq       Total Category  logprob  loglift
# 1561        mr.   44.000000   44.000000  Default  30.0000  30.0000
# 1263   increase   41.000000   41.000000  Default  29.0000  29.0000
# 5531    january   36.000000   36.000000  Default  28.0000  28.0000
# 1273     indian  115.000000  115.000000  Default  27.0000  27.0000
# 2590       work   41.000000   41.000000  Default  26.0000  26.0000
# ...         ...         ...         ...      ...      ...      ...
# 1442       line    0.000104   21.858526   Topic5  -8.8515  -1.5191
# 1126      great    0.000104   61.011177   Topic5  -8.8449  -2.5390
# 2118  secretary    0.000104   55.243462   Topic5  -8.8475  -2.4423
# 1992     report    0.000104   28.866888   Topic5  -8.8510  -1.7967
# 2473     united    0.000103   67.913338   Topic5  -8.8544  -2.6556
#
# [303 rows x 6 columns], token_table=      Topic      Freq    Term
# term
# 4         1  0.082274     $,,
# 4         2  0.905012     $,,
# 4         3  0.027425     $,,
# 5         1  0.093940    $,,,
# 5         2  0.876777    $,,,
# ...     ...       ...     ...
# 2607      1  0.452418    year
# 2607      2  0.525783    year
# 2607      3  0.024455    year
# 6141      1  0.607364  years.
# 6141      2  0.303682  years.
#
# [605 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 1, 3, 4, 2])

# %%
count = 1
for doc in speeches['processed_speech']:
    vec=dictionary.doc2bow(doc)
    print("Speech # ",count, lda[vec])
    count=count+1
# Out:
# Speech #  1 [(0, 0.26371452), (2, 0.012117065), (3, 0.0145973945), (4, 0.70956)]
# Speech #  2 [(3, 0.47146192), (4, 0.5275979)]
# Speech #  3 [(4, 0.9994769)]
# Speech #  4 [(0, 0.056601115), (2, 0.022590157), (4, 0.9207322)]
# Speech #  5 [(0, 0.015271776), (4, 0.98426884)]
# Speech #  6 [(4, 0.9991641)]
# Speech #  7 [(0, 0.06452597), (3, 0.75177056), (4, 0.18336949)]
# Speech #  8 [(4, 0.9998019)]
# Speech #  9 [(4, 0.9995298)]
# Speech #  10 [(0, 0.32498723), (2, 0.027228303), (3, 0.022563362), (4, 0.62520844)]
# Speech #  11 [(0, 0.3107095), (2, 0.056472372), (3, 0.01732302), (4, 0.6154864)]
# Speech #  12 [(0, 0.16858591), (2, 0.52347845), (4, 0.30788904)]
# Speech #  13 [(0, 0.863414), (2, 0.07718879), (4, 0.059050765)]
# Speech #  14 [(0, 0.21671194), (2, 0.16000699), (3, 0.026806144), (4, 0.59645706)]
# Speech #  15 [(0, 0.39974), (2, 0.02460175), (3, 0.016104171), (4, 0.55954474)]
# Speech #  16 [(0, 0.047917582), (2, 0.6014554), (3, 0.047454692), (4, 0.3030093)]

# %%
t=0
for i in lda.show_topics(num_topics=num_topics, num_words=5, log=False, formatted=True):
    print ("Topic # ", t , i)
    t = t + 1
# Out:
# Topic #  0 (0, '0.005*"year" + 0.004*"mr." + 0.004*"increase" + 0.004*"work" + 0.004*"january"')
# Topic #  1 (1, '0.000*"year" + 0.000*"law" + 0.000*"government" + 0.000*"silver" + 0.000*"indian"')
# Topic #  2 (2, '0.004*"hawaiian" + 0.004*"democratic" + 0.003*"police" + 0.003*"chilean" + 0.003*"government"')
# Topic #  3 (3, '0.002*"latin-american" + 0.002*"to-day" + 0.002*"treaty" + 0.002*"access" + 0.002*"markets,"')
# Topic #  4 (4, '0.005*"indian" + 0.005*"law" + 0.004*"american" + 0.004*"land" + 0.003*"public"')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
for t in range(lda.num_topics):
    plt.figure()
    plt.imshow(WordCloud().fit_words(dict(lda.show_topic(t,50))))
    plt.axis("off")
    plt.title("Topic #" + str(t))
    plt.show()

# %%
topics = [lda[corpus[i]] for i in range(len(speeches))]

def topics_document_to_dataframe(topics_document, num_topics):
    res = pd.DataFrame(columns=range(num_topics))
    for topic_weight in topics_document:
        res.loc[0, topic_weight[0]] = topic_weight[1]
    return res
document_topic=\
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics]) \
  .reset_index(drop=True).fillna(0)

# %%
import seaborn as sns
sns.heatmap(document_topic.loc[document_topic.idxmax(axis=1).sort_values().index])
plt.xlabel('Topic')
plt.ylabel('Speech')
# Out:
# Text(33.0, 0.5, 'Speech')

# %%
sns.set(rc={'figure.figsize':(10,5)})
document_topic.idxmax(axis=1).value_counts().plot.bar(color='lightblue')
