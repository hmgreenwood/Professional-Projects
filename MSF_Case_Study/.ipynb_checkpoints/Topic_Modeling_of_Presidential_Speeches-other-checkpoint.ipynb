# %%
import pandas as pd
import numpy as np
import scipy as sp
import gensim
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from textblob import TextBlob, Word
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import *
# %matplotlib inline

# %%
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim import corpora, models, matutils

# %% [markdown]
# Importing all Presidential speeches and appending them to a dataframe

# %%
from os import path
from pathlib import Path
import os
import glob
from collections import defaultdict
root=r'C:\Users\hartg\Desktop\Professional_Projects\Professional-Projects\MSF_Case_Study\Corpus of Presential Speeches\wilson'
files=os.listdir(root)

#load speeches into a list

docs=list()
for file in files:
    with open(path.join(root,file),'r',encoding='utf-8') as fd:
        txt=fd.read()
        docs.append(txt)

# %% [markdown]
# Function that "cleans" the speeches. Re (regular expression) replaces special characters with, in this case, nothing. This will remove the <title=> characters, etc

# %%
import re
def clean(doc):
    doc = re.sub(r'[^\w\s]*','',doc)
    doc = re.sub(r'[\s]+', ' ', doc)
    doc = doc.lower().strip()
    return doc

# %% [markdown]
# clean the documents associated with the presidential speeches

# %%
clean_docs=list()
for doc in docs:
    doc = clean(doc)
    clean_docs.append(doc)

# %%
speeches_df=pd.DataFrame(docs)
speeches_df.columns=['text']

# %%
speeches_df.head()
# Out:
#                                                 text
# 0  <title="First Inaugural Address">\n<date="Marc...
# 1  <title="Message Regarding Tariff Duties">\n<da...
# 2  <title="Message Regarding Banking System">\n<d...
# 3  <title="Address at Gettysburg">\n<date="July 4...
# 4  <title="First Annual Message">\n<date="Decembe...

# %%
new_df=speeches_df['text'].str.split("=",n=1,expand=True)
new_df.columns=['title_bad','title_actual']
new_df.head()
# Out:
#   title_bad                                       title_actual
# 0    <title  "First Inaugural Address">\n<date="March 4, 19...
# 1    <title  "Message Regarding Tariff Duties">\n<date="Apr...
# 2    <title  "Message Regarding Banking System">\n<date="Ju...
# 3    <title  "Address at Gettysburg">\n<date="July 4, 1913"...
# 4    <title  "First Annual Message">\n<date="December 2, 19...

# %%
new_df2=new_df['title_actual'].str.split("=",n=1,expand=True)
new_df2.columns=['title','date_and_text']
new_df2.head()
# Out:
#                                         title  \
# 0           "First Inaugural Address">\n<date
# 1   "Message Regarding Tariff Duties">\n<date
# 2  "Message Regarding Banking System">\n<date
# 3             "Address at Gettysburg">\n<date
# 4              "First Annual Message">\n<date
#
#                                        date_and_text
# 0  "March 4, 1913">\n\nThere has been a change of...
# 1  "April 8, 1913">\nMr. Speaker, Mr. President, ...
# 2  "June 23, 1913">\nMr. Speaker, Mr. President, ...
# 3  "July 4, 1913">\nFriends and Fellow Citizens:\...
# 4  "December 2, 1913">\nGentlemen of the Congress...

# %%
new_df3=new_df2['date_and_text'].str.split(">",n=1,expand=True)
new_df3.columns=['date','text']

# %%
new_df3.head()
# Out:
#                  date                                               text
# 0     "March 4, 1913"  \n\nThere has been a change of government. It ...
# 1     "April 8, 1913"  \nMr. Speaker, Mr. President, Gentlemen of the...
# 2     "June 23, 1913"  \nMr. Speaker, Mr. President, Gentlemen of the...
# 3      "July 4, 1913"  \nFriends and Fellow Citizens:\nI need not tel...
# 4  "December 2, 1913"  \nGentlemen of the Congress:\nIn pursuance of ...

# %%
speeches=pd.merge(new_df2,new_df3,left_index=True,right_index=True)

# %%
speeches.head()
# Out:
#                                         title  \
# 0           "First Inaugural Address">\n<date
# 1   "Message Regarding Tariff Duties">\n<date
# 2  "Message Regarding Banking System">\n<date
# 3             "Address at Gettysburg">\n<date
# 4              "First Annual Message">\n<date
#
#                                        date_and_text                date  \
# 0  "March 4, 1913">\n\nThere has been a change of...     "March 4, 1913"
# 1  "April 8, 1913">\nMr. Speaker, Mr. President, ...     "April 8, 1913"
# 2  "June 23, 1913">\nMr. Speaker, Mr. President, ...     "June 23, 1913"
# 3  "July 4, 1913">\nFriends and Fellow Citizens:\...      "July 4, 1913"
# 4  "December 2, 1913">\nGentlemen of the Congress...  "December 2, 1913"
#
#                                                 text
# 0  \n\nThere has been a change of government. It ...
# 1  \nMr. Speaker, Mr. President, Gentlemen of the...
# 2  \nMr. Speaker, Mr. President, Gentlemen of the...
# 3  \nFriends and Fellow Citizens:\nI need not tel...
# 4  \nGentlemen of the Congress:\nIn pursuance of ...

# %%
speeches.drop(['date_and_text'],axis=1,inplace=True)

# %%
speeches['title']=speeches.title.str.replace('>\n<date','',regex=True)
speeches.head()
# Out:
#                                 title                date  \
# 0           "First Inaugural Address"     "March 4, 1913"
# 1   "Message Regarding Tariff Duties"     "April 8, 1913"
# 2  "Message Regarding Banking System"     "June 23, 1913"
# 3             "Address at Gettysburg"      "July 4, 1913"
# 4              "First Annual Message"  "December 2, 1913"
#
#                                                 text
# 0  \n\nThere has been a change of government. It ...
# 1  \nMr. Speaker, Mr. President, Gentlemen of the...
# 2  \nMr. Speaker, Mr. President, Gentlemen of the...
# 3  \nFriends and Fellow Citizens:\nI need not tel...
# 4  \nGentlemen of the Congress:\nIn pursuance of ...

# %%
speeches['date']=speeches.date.str.replace('"','',regex=True)
speeches.head()
# Out:
#                                 title              date  \
# 0           "First Inaugural Address"     March 4, 1913
# 1   "Message Regarding Tariff Duties"     April 8, 1913
# 2  "Message Regarding Banking System"     June 23, 1913
# 3             "Address at Gettysburg"      July 4, 1913
# 4              "First Annual Message"  December 2, 1913
#
#                                                 text
# 0  \n\nThere has been a change of government. It ...
# 1  \nMr. Speaker, Mr. President, Gentlemen of the...
# 2  \nMr. Speaker, Mr. President, Gentlemen of the...
# 3  \nFriends and Fellow Citizens:\nI need not tel...
# 4  \nGentlemen of the Congress:\nIn pursuance of ...

# %%
speeches['text']=speeches.text.str.replace("\n",'',regex=True)
speeches.head()
# Out:
#                                 title              date  \
# 0           "First Inaugural Address"     March 4, 1913
# 1   "Message Regarding Tariff Duties"     April 8, 1913
# 2  "Message Regarding Banking System"     June 23, 1913
# 3             "Address at Gettysburg"      July 4, 1913
# 4              "First Annual Message"  December 2, 1913
#
#                                                 text
# 0  There has been a change of government. It bega...
# 1  Mr. Speaker, Mr. President, Gentlemen of the C...
# 2  Mr. Speaker, Mr. President, Gentlemen of the C...
# 3  Friends and Fellow Citizens:I need not tell yo...
# 4  Gentlemen of the Congress:In pursuance of my c...

# %% [markdown]
# Dropping indeces 208,801, and 814 as they were not appropriately transformed upon import

# %%
#speeches['date']=pd.to_datetime(speeches['date'])

# %%
speeches['text']=speeches['text'].str.lower()

# %% [markdown]
# Loading stopwords from NLTK

# %%
from nltk.corpus import stopwords

# %%
from gensim.parsing.preprocessing import preprocess_string
from gensim.parsing.preprocessing import strip_tags,strip_punctuation,strip_numeric,stem_text
from gensim.parsing.preprocessing import strip_multiple_whitespaces,strip_non_alphanum,remove_stopwords,strip_short
import pattern
import nltk

# %%
Filtering=[lambda x: x.lower(),strip_multiple_whitespaces,
          strip_numeric,
          remove_stopwords,
          strip_short]

# %%
def preprocess(text):
    result=[]
    for token in preprocess_string(text,Filtering):
        result.append(token)
    return result
speeches['processed_speech']=speeches['text'].map(preprocess)

# %%
lemmatizer=nltk.stem.WordNetLemmatizer()
def lemmatize_text(text):
    return[lemmatizer.lemmatize(w) for w in text]

# %%
speeches['processed_speech']=speeches.processed_speech.apply(lemmatize_text)

# %%
speeches['bigrams']=speeches.processed_speech.apply(lambda row: list(nltk.ngrams(row,2)))

# %%
from gensim import corpora,models,similarities
dictionary=corpora.Dictionary(speeches.processed_speech)

# %% [markdown]
# Creating the corpus of documents. Doc2Bow counts the number of occurences of each distinct word and converts the word to an integer word ID. Returns a sparse vector

# %%
corpus=[dictionary.doc2bow(text) for text in speeches.processed_speech]

# %% [markdown]
# Building a TF-IDF Model (Term Frequency Inverse Document Frequency)

# %%
tfidf=models.TfidfModel(corpus)
transformed_tfidf = tfidf[corpus]

# %% [markdown]
# LDA (Latent Dirichlet Allocation) on TF-IDF

# %%
num_topics=5
# %time lda = models.LdaModel(transformed_tfidf,id2word=dictionary,num_topics=num_topics,passes=4,alpha=[.01]*num_topics,eta=[.01]*len(dictionary.keys()))
# Out:
# Wall time: 1.15 s

# %%
lda.show_topics()
# Out:
# [(0,
#   '0.004*"registration" + 0.004*"declaration" + 0.002*"county" + 0.002*"patriotic" + 0.002*"independence" + 0.002*"cruisers," + 0.002*"person" + 0.002*"officer" + 0.002*"clerk" + 0.002*"submarines,"'),
#  (1,
#   '0.006*"business" + 0.006*"german" + 0.004*"peace" + 0.004*"imperial" + 0.003*"people" + 0.003*"submarine" + 0.003*"neutral" + 0.003*"shall" + 0.003*"country" + 0.002*"ship"'),
#  (2,
#   '0.004*"huerta" + 0.004*"alien" + 0.003*"enemy" + 0.002*"faith" + 0.002*"to-night" + 0.002*"democracy" + 0.002*"apology" + 0.002*"paymaster" + 0.002*"section" + 0.002*"arrest"'),
#  (3,
#   '0.003*"tariff" + 0.003*"test" + 0.002*"praise" + 0.002*"quality" + 0.002*"fiscal" + 0.002*"lady" + 0.002*"interstate" + 0.002*"union." + 0.002*"asylum" + 0.002*"sooner"'),
#  (4,
#   '0.001*"equip" + 0.000*"food" + 0.000*"hundred" + 0.000*"clothe" + 0.000*"abundant" + 0.000*"farmer" + 0.000*"supreme" + 0.000*"factory" + 0.000*"shipment" + 0.000*"thousands,"')]

# %%
import pyLDAvis.gensim
pyLDAvis.enable_notebook()
vis=pyLDAvis.gensim.prepare(lda,corpus,dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 1      0.111211 -0.000737       1        1  92.451378
# 2     -0.034104 -0.022769       2        1   2.954640
# 0     -0.026020  0.000391       3        1   2.445029
# 3     -0.029606  0.023120       4        1   2.146010
# 4     -0.021480 -0.000005       5        1   0.002933, topic_info=         Term       Freq      Total Category  logprob  loglift
# 1182    enemy  33.000000  33.000000  Default  30.0000  30.0000
# 3289   person  33.000000  33.000000  Default  29.0000  29.0000
# 3819    faith  27.000000  27.000000  Default  28.0000  28.0000
# 1960  states,  30.000000  30.000000  Default  27.0000  27.0000
# 1647   farmer  48.000000  48.000000  Default  26.0000  26.0000
# ...       ...        ...        ...      ...      ...      ...
# 277       let   0.000213  55.468716   Topic5  -8.4204  -2.0326
# 269     labor   0.000210  50.857388   Topic5  -8.4375  -1.9628
# 4035     road   0.000201  41.694035   Topic5  -8.4768  -1.8035
# 1947     ship   0.000199  76.340027   Topic5  -8.4871  -2.4186
# 3376    trade   0.000195  56.693878   Topic5  -8.5068  -2.1408
#
# [234 rows x 6 columns], token_table=      Topic      Freq       Term
# term
# 1385      1  0.902250   abundant
# 557       1  0.808508  accompany
# 557       4  0.404254  accompany
# 3643      1  0.653032       act,
# 3643      3  0.326516       act,
# ...     ...       ...        ...
# 545       1  0.699178      woman
# 545       2  0.174795      woman
# 2717      1  0.998344       word
# 3399      1  0.638418      year,
# 3399      3  0.319209      year,
#
# [317 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 3, 1, 4, 5])

# %%
count = 1
for doc in speeches['processed_speech']:
    vec=dictionary.doc2bow(doc)
    print("Speech # ",count, lda[vec])
    count=count+1
# Out:
# Speech #  1 [(1, 0.9553983), (2, 0.028973747), (3, 0.015523397)]
# Speech #  2 [(1, 0.80812097), (3, 0.19169915)]
# Speech #  3 [(1, 0.9782067), (3, 0.021587446)]
# Speech #  4 [(1, 0.911589), (2, 0.08227274)]
# Speech #  5 [(1, 0.9885007)]
# Speech #  6 [(0, 0.031253945), (1, 0.9552744), (3, 0.0133595)]
# Speech #  7 [(1, 0.70801765), (2, 0.27843696)]
# Speech #  8 [(1, 0.60596895), (3, 0.39373925)]
# Speech #  9 [(0, 0.13097955), (1, 0.8512076), (2, 0.01776282)]
# Speech #  10 [(1, 0.9939747)]
# Speech #  11 [(1, 0.77337474), (2, 0.025720742), (3, 0.20072335)]
# Speech #  12 [(1, 0.9997926)]
# Speech #  13 [(1, 0.99992895)]
# Speech #  14 [(1, 0.9997403)]
# Speech #  15 [(1, 0.8570982), (2, 0.14268559)]
# Speech #  16 [(1, 0.9784008), (3, 0.017343486)]
# Speech #  17 [(1, 0.999895)]
# Speech #  18 [(0, 0.1013205), (1, 0.86402404), (2, 0.021049784), (3, 0.013594613)]
# Speech #  19 [(1, 0.9998804)]
# Speech #  20 [(1, 0.9973746)]
# Speech #  21 [(1, 0.8234888), (3, 0.17640363)]
# Speech #  22 [(1, 0.99991906)]
# Speech #  23 [(1, 0.9561502), (2, 0.029486794)]
# Speech #  24 [(1, 0.6794554), (2, 0.31331226)]
# Speech #  25 [(1, 0.9998429)]
# Speech #  26 [(1, 0.99993175)]
# Speech #  27 [(0, 0.32393533), (1, 0.6282838), (2, 0.04770729)]
# Speech #  28 [(1, 0.9756208)]
# Speech #  29 [(1, 0.9912757)]
# Speech #  30 [(1, 0.97906303), (2, 0.015564187)]
# Speech #  31 [(1, 0.95647717), (2, 0.011686294), (3, 0.031797294)]
# Speech #  32 [(1, 0.767763), (2, 0.203356), (3, 0.022981117)]

# %%
t=0
for i in lda.show_topics(num_topics=num_topics, num_words=5, log=False, formatted=True):
    print ("Topic # ", t , i)
    t = t + 1
# Out:
# Topic #  0 (0, '0.004*"registration" + 0.004*"declaration" + 0.002*"county" + 0.002*"patriotic" + 0.002*"independence"')
# Topic #  1 (1, '0.006*"business" + 0.006*"german" + 0.004*"peace" + 0.004*"imperial" + 0.003*"people"')
# Topic #  2 (2, '0.004*"huerta" + 0.004*"alien" + 0.003*"enemy" + 0.002*"faith" + 0.002*"to-night"')
# Topic #  3 (3, '0.003*"tariff" + 0.003*"test" + 0.002*"praise" + 0.002*"quality" + 0.002*"fiscal"')
# Topic #  4 (4, '0.001*"equip" + 0.000*"food" + 0.000*"hundred" + 0.000*"clothe" + 0.000*"abundant"')

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
for t in range(lda.num_topics):
    plt.figure()
    plt.imshow(WordCloud().fit_words(dict(lda.show_topic(t,50))))
    plt.axis("off")
    plt.title("Topic #" + str(t))
    plt.show()

# %%
topics = [lda[corpus[i]] for i in range(len(speeches))]

def topics_document_to_dataframe(topics_document, num_topics):
    res = pd.DataFrame(columns=range(num_topics))
    for topic_weight in topics_document:
        res.loc[0, topic_weight[0]] = topic_weight[1]
    return res
document_topic=\
pd.concat([topics_document_to_dataframe(topics_document, num_topics=num_topics) for topics_document in topics]) \
  .reset_index(drop=True).fillna(0)

# %%
import seaborn as sns
sns.heatmap(document_topic.loc[document_topic.idxmax(axis=1).sort_values().index])
plt.xlabel('Topic')
plt.ylabel('Speech')
# Out:
# Text(30.5, 0.5, 'Speech')

# %%
sns.set(rc={'figure.figsize':(10,5)})
document_topic.idxmax(axis=1).value_counts().plot.bar(color='lightblue')
